# %% [markdown]
# # Google Play Store EDA

# %% [markdown]
# [Google Play Store Dashboard](https://datastudio.google.com/s/qGCQq1wbFd4)
#
# [Submit Form](https://docs.google.com/forms/d/e/1FAIpQLSfIX3BUFxr2DwR59lws8S5RsMAfv8lTb7k_ztuDrz5soWZDYQ/viewform)

# %%
from IPython.display import IFrame
IFrame('https://datastudio.google.com/embed/reporting/1GXPRZolva6sp22nDRyOfGYMhb9BQOQcE/page/QNfx', \
       width='867px', height='650px')
# Out:
#         <iframe
#             width="867px"
#             height="650px"
#             src="https://datastudio.google.com/embed/reporting/1GXPRZolva6sp22nDRyOfGYMhb9BQOQcE/page/QNfx"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Preparation

# %% [markdown]
# ### Config & import tools

# %%
# %config InlineBackend.figure_format ='retina'
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style("whitegrid")
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load dataset

# %%
apps = pd.read_csv('google-play-store.csv')

# %% [markdown]
# ### Reading dataset description

# %% [markdown]
# 10k Play Store apps for analysing
#
# **Columns**
# 1. App: *Application name*
# 2. Category: *Category the app belongs to*
# 3. Rating: *Overall user rating of the app (as when scraped)*
# 4. Reviews: *Number of user reviews for the app (as when scraped)*
# 5. Size: *Size of the app (as when scraped)*
# 6. Installs: *Number of user downloads/installs for the app (as when scraped)*
# 7. Type: *Paid or Free*
# 8. Price: *Price of the app (as when scraped)*
# 9. Content Rating: *Age group the app is targeted at - Children / Mature 21+ / Adult*
# 10. Genres: *An app can belong to multiple genres (apart from its main category). For eg, a musical family game will belong to Music, Game, Family genres.*
# 11. Last Updated: *Date when the app was last updated on Play Store (as when scraped)*
# 12. Current Ver: *Current version of the app available on Play Store (as when scraped)*
# 13. Android Ver: *Min required Android version (as when scraped)*
#
# **Updated:** Sun Feb 03 2019 20:55:47 GMT+0700 (Indochina Time)

# %% [markdown]
# ### Infomations

# %%
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
apps.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# Look like most of columns does not belong to its type

# %%
apps.sample(5)
# Out:
#                                 App         Category  Rating Reviews  \
# 996                      Funny Pics    ENTERTAINMENT     3.9    9941
# 4391             Traps n' Gemstones             GAME     4.5     413
# 7142                     Cb browser    COMMUNICATION     5.0       5
# 3415  Northern Lights FREE (Aurora)  PERSONALIZATION     4.1   12180
# 2391   Complete Anatomy for Android          MEDICAL     4.1      90
#
#                     Size    Installs  Type  Price Content Rating  \
# 996   Varies with device  1,000,000+  Free      0           Teen
# 4391                9.1M      1,000+  Paid  $4.99       Everyone
# 7142                3.7M         50+  Free      0       Everyone
# 3415                5.4M  1,000,000+  Free      0       Everyone
# 2391                 21M      1,000+  Free      0       Everyone
#
#                Genres       Last Updated         Current Ver  \
# 996     Entertainment       July 7, 2017  Varies with device
# 4391        Adventure       May 17, 2017                1.04
# 7142    Communication      April 2, 2018                 1.0
# 3415  Personalization  December 24, 2016                 1.3
# 2391          Medical      July 11, 2018               1.0.0
#
#              Android Ver
# 996   Varies with device
# 4391        4.0.3 and up
# 7142          4.0 and up
# 3415          2.1 and up
# 2391          7.0 and up

# %% [markdown]
# It seems that:
# - "Category", "Genres", "Type", "Content Rating", "Android Ver" should be categorical
# - "Rating" already float and "Price" should be float
# - "Size" seems a little bit tricky => float in MB
# - "Reviews", "Installs" should be int
# - Should we decode "Installs"?
# - "Last Updated" should be date

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# ### Drop duplicated rows

# %% [markdown]
# Drop duplicates

# %%
apps.drop_duplicates(subset = None, keep = 'last', inplace = True)

# %% [markdown]
# Check for app name duplicated

# %%
apps[apps['App'].duplicated()].sort_values(by = 'App')
# Out:
#                                                      App             Category  \
# 5415                             365Scores - Live Scores               SPORTS
# 1871                                         8 Ball Pool                 GAME
# 1970                                         8 Ball Pool                 GAME
# 1755                                         8 Ball Pool                 GAME
# 3953                                         8 Ball Pool               SPORTS
# 1844                                         8 Ball Pool                 GAME
# 1703                                         8 Ball Pool                 GAME
# 662                      95Live -SG#1 Live Streaming App               DATING
# 4991               A&E - Watch Full Episodes of TV Shows               FAMILY
# 4928                       AC - Tips & News for Android™   NEWS_AND_MAGAZINES
# 5448                           AP Mobile - Breaking News   NEWS_AND_MAGAZINES
# 2800                                                ASOS             SHOPPING
# 5512   AccuWeather: Daily Forecast & Live Weather Rep...              WEATHER
# 1143                        Acorns - Invest Spare Change              FINANCE
# 3524                                Adobe Acrobat Reader         PRODUCTIVITY
# 3895                                Adobe Acrobat Reader         PRODUCTIVITY
# 2936   Adobe Photoshop Express:Photo Editor Collage M...          PHOTOGRAPHY
# 3880                                             Agar.io                 GAME
# 3215                                              Airbnb     TRAVEL_AND_LOCAL
# 2756        AliExpress - Smarter Shopping, Better Living             SHOPPING
# 2790        AliExpress - Smarter Shopping, Better Living             SHOPPING
# 4099        AliExpress - Smarter Shopping, Better Living             SHOPPING
# 5075                 All Football - Latest News & Videos               SPORTS
# 10171                                All Social Networks               SOCIAL
# 3936                                    Alto's Adventure                 GAME
# 4083                                       Amazon Kindle  BOOKS_AND_REFERENCE
# 2763                                     Amazon Shopping             SHOPPING
# 3922                                     Amazon Shopping             SHOPPING
# 5353                                  Amazon for Tablets             SHOPPING
# 5952                                   American Airlines     TRAVEL_AND_LOCAL
# ...                                                  ...                  ...
# 1948                                  Zombie Hunter King                 GAME
# 1728                                  Zombie Hunter King                 GAME
# 1874                                  Zombie Hunter King                 GAME
# 3940                                      Zombie Tsunami                 GAME
# 1914                                      Zombie Tsunami                 GAME
# 1730                                      Zombie Tsunami                 GAME
# 2008                                      Zombie Tsunami                 GAME
# 7077                      Zoosk Dating App: Meet Singles               DATING
# 5863                         ai.type Free Emoji Keyboard      PERSONALIZATION
# 9635    busuu: Learn Languages - Spanish, English & More               FAMILY
# 846     busuu: Learn Languages - Spanish, English & More            EDUCATION
# 4068   eBay: Buy & Sell this Summer - Discover Deals ...             SHOPPING
# 789          edX - Online Courses by Harvard, MIT & more            EDUCATION
# 4224                           free video calls and chat        COMMUNICATION
# 4222                       imo free video calls and chat        COMMUNICATION
# 4322    letgo: Buy & Sell Used Stuff, Cars & Real Estate             SHOPPING
# 673    muzmatch: Muslim & Arab Singles, Marriage & Da...               DATING
# 2008    Everyone 10+             Arcade      June 15, 2018
# 7077      Mature 17+             Dating     August 2, 2018
# 5863        Everyone    Personalization      July 24, 2018
# 9635    Everyone 10+          Education     August 1, 2018
# 846     Everyone 10+          Education     August 1, 2018
# 4068            Teen           Shopping      July 30, 2018
# 789     Everyone 10+          Education      July 15, 2018
# 4224        Everyone      Communication      July 19, 2018
# 4222        Everyone      Communication       June 8, 2018
# 4322            Teen           Shopping     August 2, 2018
# 673       Mature 17+             Dating      July 24, 2018
# 4593        Everyone       Productivity      July 18, 2018
# 6194        Everyone            Medical      July 23, 2018
# 2618        Everyone             Social   October 16, 2017
# 10473       Everyone              Tools     August 7, 2018
# 5664        Everyone       House & Home      July 16, 2018
# 1921        Everyone             Action  November 14, 2017
# 4227        Everyone             Action  November 14, 2017
# 1735        Everyone             Action  November 14, 2017
# 1757        Everyone             Action  November 14, 2017
# 565       Mature 17+             Dating       July 7, 2018
# 2637        Everyone             Social      July 26, 2018
# 3085    Everyone 10+             Sports      July 25, 2018
# 8291        Everyone            Weather     August 6, 2018
#
#               Current Ver         Android Ver
# 5415                5.5.9          4.1 and up
# 1871                4.0.0        4.0.3 and up
# 1970                4.0.0        4.0.3 and up
# 1755                4.0.0        4.0.3 and up
# 3953                4.0.0        4.0.3 and up
# 1844                4.0.0        4.0.3 and up
# 1703                4.0.0        4.0.3 and up
# 662                 8.7.2          4.2 and up
# 4991                3.1.4          4.4 and up
# 4928               3.1.12          4.1 and up
# 5448                4.4.3          4.0 and up
# 2800                4.4.9          4.4 and up
# 5512   Varies with device  Varies with device
# 1143   Varies with device  Varies with device
# 3524   Varies with device  Varies with device
# 3895   Varies with device  Varies with device
# 2936              5.0.508          4.4 and up
# 3880                2.2.8        4.0.3 and up
# 3215   Varies with device  Varies with device
# 2756   Varies with device  Varies with device
# 2790   Varies with device  Varies with device
# 4099   Varies with device  Varies with device
# 5075                3.0.5          4.1 and up
# 10171              2.4.12          4.0 and up
# 3936                1.7.1          4.0 and up
# 4083   Varies with device  Varies with device
# 2763          16.14.0.100          4.4 and up
# 3922          16.14.0.100          4.4 and up
# 5353          16.14.0.850          4.4 and up
# 5952   Varies with device  Varies with device
# ...                   ...                 ...
# 1948                1.0.8          2.3 and up
# 1728                1.0.8          2.3 and up
# 1874                1.0.8          2.3 and up
# 3940   Varies with device  Varies with device
# 1914   Varies with device  Varies with device
# 1730   Varies with device  Varies with device
# 2008   Varies with device  Varies with device
# 7077   Varies with device  Varies with device
# 5863   Varies with device  Varies with device
# 9635           13.9.0.161          5.0 and up
# 846            13.9.0.161          5.0 and up
# 4068   Varies with device  Varies with device
# 789                2.15.1          4.1 and up
# 4224          7.3(800241)          4.4 and up
# 4222     9.8.000000010501          4.0 and up
# 4322                2.4.8          4.1 and up
# 673               3.8.75a        4.0.3 and up
# 4593   Varies with device          5.0 and up
# 6194               3.52.0          5.0 and up
# 2618                4.2.1          4.3 and up
# 10473             6.06.14          4.4 and up
# 5664   Varies with device  Varies with device
# 1921   Varies with device          2.3 and up
# 4227   Varies with device          2.3 and up
# 1735   Varies with device          2.3 and up
# 1757   Varies with device          2.3 and up
# 565                 2.4.1          4.1 and up
# 2637                7.3.1          4.1 and up
# 3085               6.17.2          4.4 and up
# 8291   Varies with device  Varies with device
#
# [698 rows x 13 columns]

# %% [markdown]
# ~700 rows, damn, thats a lot. So goodbye, duplicates!

# %%
apps.drop_duplicates(subset = ['App'], keep = 'last', inplace = True)

# %% [markdown]
# ### Category column

# %%
# Cast category to category type
apps['Category'] = apps['Category'].astype('category')

# %%
apps['Category'].value_counts()
# Out:
# FAMILY                 1906
# GAME                    926
# TOOLS                   829
# BUSINESS                419
# MEDICAL                 396
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  327
# COMMUNICATION           316
# HEALTH_AND_FITNESS      287
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     222
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  170
# VIDEO_PLAYERS           163
# MAPS_AND_NAVIGATION     131
# FOOD_AND_DRINK          112
# EDUCATION               102
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  79
# ENTERTAINMENT            79
# HOUSE_AND_HOME           73
# EVENTS                   64
# ART_AND_DESIGN           61
# PARENTING                60
# COMICS                   56
# BEAUTY                   53
# 1.9                       1
# Name: Category, dtype: int64

# %% [markdown]
# ### Reviews column

# %% [markdown]
# Reviews column should contains only number, so lets check for non-number chars

# %%
apps[apps['Reviews'].str.contains(r'\D')]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# Look at that row: the category, rating, size, installs,.... all columns seems so wrong?
#
# Lets get rid of this meaningless row!

# %%
# Drop it cold-bloodly
apps.drop(10472, inplace=True)

# %% [markdown]
# Gotta cast 'em all!

# %%
apps['Reviews'] = apps['Reviews'].astype('int')

# %% [markdown]
# ### Size column

# %%
apps['Size'].unique()
# Out:
# array(['19M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M', '28M',
#        '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M', '31M',
#        '14M', '4.2M', '23M', '6.0M', '6.1M', '4.6M', '9.2M', '5.2M',
#        '11M', 'Varies with device', '9.4M', '15M', '10M', '1.2M', '24M',
#        '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k', '3.6M',
#        '5.7M', '8.6M', '2.4M', '27M', '2.5M', '7.0M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '46M', '51M', '48M', '8.5M', '41M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '8.4M', '118k', '44M', '695k', '1.6M', '18k', '53M',
#        '6.2M', '3.0M', '5.8M', '3.8M', '9.6M', '45M', '63M', '49M',
#        '4.4M', '70M', '6.9M', '9.3M', '10.0M', '8.1M', '4.8M', '36M',
#        '77M', '84M', '97M', '2.0M', '1.9M', '1.8M', '5.3M', '47M', '556k',
#        '526k', '7.6M', '76M', '9.7M', '78M', '72M', '43M', '7.7M', '6.3M',
#        '334k', '1.4M', '34M', '93M', '65M', '100M', '50M', '68M', '79M',
#        '64M', '67M', '94M', '59M', '60M', '58M', '232k', '99M', '624k',
#        '95M', '8.5k', '41k', '292k', '11k', '80M', '1.7M', '69M', '71M',
#        '62M', '98M', '85M', '86M', '82M', '81M', '96M', '91M', '83M',
#        '87M', '66M', '75M', '92M', '862k', '899k', '378k', '266k', '375k',
#        '74M', '1.3M', '975k', '980k', '4.1M', '89M', '88M', '696k',
#        '544k', '525k', '920k', '779k', '853k', '720k', '713k', '772k',
#        '318k', '58k', '241k', '196k', '857k', '51k', '953k', '865k',
#        '251k', '930k', '540k', '313k', '746k', '203k', '26k', '314k',
#        '79k', '239k', '371k', '220k', '730k', '756k', '91k', '293k',
#        '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k', '81k',
#        '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '704k', '887k', '613k', '243k', '569k', '778k', '683k',
#        '592k', '319k', '186k', '840k', '647k', '191k', '373k', '437k',
#        '598k', '716k', '585k', '982k', '222k', '219k', '55k', '948k',
#        '323k', '691k', '511k', '951k', '963k', '25k', '554k', '351k',
#        '27k', '82k', '208k', '913k', '514k', '551k', '29k', '103k',
#        '898k', '743k', '116k', '153k', '209k', '353k', '499k', '173k',
#        '597k', '809k', '122k', '411k', '400k', '801k', '787k', '237k',
#        '50k', '643k', '986k', '97k', '516k', '837k', '780k', '961k',
#        '269k', '20k', '498k', '600k', '749k', '642k', '881k', '72k',
#        '656k', '601k', '221k', '228k', '108k', '940k', '176k', '33k',
#        '663k', '34k', '942k', '259k', '164k', '458k', '245k', '629k',
#        '28k', '288k', '775k', '785k', '636k', '916k', '994k', '309k',
#        '485k', '914k', '903k', '608k', '500k', '54k', '562k', '847k',
#        '957k', '688k', '811k', '270k', '48k', '329k', '523k', '921k',
#        '874k', '981k', '784k', '280k', '24k', '518k', '754k', '892k',
#        '154k', '860k', '364k', '387k', '626k', '161k', '879k', '39k',
#        '970k', '170k', '141k', '160k', '144k', '143k', '190k', '376k',
#        '193k', '246k', '73k', '658k', '992k', '253k', '420k', '404k',
#        '470k', '226k', '240k', '89k', '234k', '257k', '861k', '467k',
#        '157k', '44k', '676k', '67k', '552k', '885k', '1020k', '582k',
#        '619k'], dtype=object)

# %% [markdown]
# They are in the format of MB (M,m) and KB (K,k) => lets go for MB (because KB is kinda small unit)
#
# "Varies with device" hmm? Lets fill them with the mean value of size, after grouped by category? (i think that will be the best solution)

# %%
apps[apps['Size'].str.contains(r'[^MmKke]$', regex = True)]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# Just do some check if there are some strange value that did not get caught by my eyes heh.
#
# Everything is allright, lets dig in

# %%
# Convert size to MB
apps['Size'] = apps['Size'].str.upper() \
                .replace('VARIES WITH DEVICE', np.nan) \
                .str.replace('+', '') \
                .str.replace(',', '')
apps['Size'] = apps['Size'].str.replace(r'[MK]', '', regex=True).astype(float) \
                / apps['Size'].str.extract(r'(K)', expand=False) \
                .fillna(1) \
                .replace('K', 10**3) \
                .astype(int)

# Fill NA with mean value of category
apps['Size'].fillna(apps.groupby('Category')['Size'].transform('mean'), inplace = True)

# Cast to int
apps['Size'] = apps['Size'].astype('int')

# %% [markdown]
# ### Installs column

# %%
apps['Installs'].unique()
# Out:
# array(['10,000+', '5,000,000+', '50,000,000+', '100,000+', '50,000+',
#        '1,000,000+', '10,000,000+', '5,000+', '500,000+',
#        '1,000,000,000+', '100,000,000+', '1,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '500,000,000+', '0+', '0'], dtype=object)

# %% [markdown]
# I think "Installs" can be categorical, right?
#
# But since "Installs" is so important, like the main character in the movie, its represent the popular of the apps, so let just cast to int

# %%
apps['Installs'] = apps['Installs'].str.replace(r'[,+]','', regex=True)
apps['Installs'] = apps['Installs'].astype('int')

# %% [markdown]
# ### Other columns

# %% [markdown]
# "Type" only contains "Free" and "Paid" am i right?

# %%
apps['Type'].unique()
# Out:
# array(['Free', 'Paid', nan], dtype=object)

# %% [markdown]
# Nan? Damn it

# %%
apps[apps['Type'].isna()]
# Out:
#                             App Category  Rating  Reviews  Size  Installs  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN        0    27         0
#
#      Type Price Content Rating    Genres   Last Updated         Current Ver  \
# 9148  NaN     0   Everyone 10+  Strategy  June 28, 2018  Varies with device
#
#              Android Ver
# 9148  Varies with device

# %% [markdown]
# Look like another strange row has appeared. So goodbye you badluck-row!

# %%
apps.drop(9148, inplace=True)

# %%
# Cast type to categorical
apps['Type'] = apps['Type'].astype('category')

# %%
apps['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$1.49', '$2.99', '$7.99', '$3.49', '$1.99',
#        '$5.99', '$6.99', '$9.99', '$7.49', '$0.99', '$1.00', '$2.49',
#        '$10.99', '$1.50', '$14.99', '$15.99', '$79.99', '$9.00', '$10.00',
#        '$16.99', '$11.99', '$29.99', '$74.99', '$5.49', '$33.99',
#        '$24.99', '$39.99', '$19.99', '$4.49', '$1.70', '$8.99', '$2.00',
#        '$3.88', '$25.99', '$399.99', '$17.99', '$400.00', '$3.02',
#        '$1.76', '$4.84', '$4.77', '$1.61', '$2.50', '$1.59', '$6.49',
#        '$1.29', '$5.00', '$13.99', '$299.99', '$379.99', '$37.99',
#        '$18.99', '$389.99', '$19.90', '$8.49', '$1.75', '$14.00', '$4.85',
#        '$46.99', '$109.99', '$3.95', '$154.99', '$3.08', '$2.59', '$4.80',
#        '$1.96', '$19.40', '$3.90', '$4.59', '$15.46', '$3.04', '$12.99',
#        '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95', '$2.90',
#        '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', '$1.20', '$1.04'], dtype=object)

# %% [markdown]
# Lets just remove the dollar-sign ($) and we are good to change type

# %%
# Cast price to float ($ unit)
apps['Price'] = apps['Price'] \
                .str.replace('$', '') \
                .astype('float')

# %% [markdown]
# I have an idea: these price in number cant speaking things, so i decide to handle them, like:

# %%
# Price banding
apps.loc[ apps['Price'] == 0, 'PriceBand'] = 'Free'
apps.loc[(apps['Price'] > 0) & (apps['Price'] <= 0.99), 'PriceBand'] = 'Cheap'
apps.loc[(apps['Price'] > 0.99) & (apps['Price'] <= 2.99), 'PriceBand']   = 'Not cheap'
apps.loc[(apps['Price'] > 2.99) & (apps['Price'] <= 4.99), 'PriceBand']   = 'Normal'
apps.loc[(apps['Price'] > 4.99) & (apps['Price'] <= 14.99), 'PriceBand']   = 'Expensive'
apps.loc[(apps['Price'] > 14.99) & (apps['Price'] <= 29.99), 'PriceBand']   = 'Too expensive'
apps.loc[(apps['Price'] > 29.99), 'PriceBand']  = 'Ridiculously expensive'

apps.sample(5)
# Out:
#                                  App   Category  Rating  Reviews  Size  \
# 8056   Theme for Tecno Camon CX / C8  LIFESTYLE     4.6      147     9
# 7206        Shiver: Moonlit Grove CE     FAMILY     4.1     3433    23
# 6970         Casa de Bolsa Bx+ Móvil    FINANCE     3.4        5     8
# 4149                   Offroad Car G     FAMILY     4.3    64884    37
# 1963  Dinosaur Simulator: Dino World       GAME     4.0    26649    66
#
#       Installs  Type  Price Content Rating      Genres    Last Updated  \
# 8056     10000  Free    0.0       Everyone   Lifestyle     May 2, 2017
# 7206     50000  Free    0.0   Everyone 10+      Casual  March 14, 2016
# 6970       500  Free    0.0       Everyone     Finance   July 18, 2017
# 4149   5000000  Free    0.0       Everyone  Simulation   July 12, 2016
# 1963   5000000  Free    0.0           Teen      Action  August 5, 2018
#
#      Current Ver   Android Ver PriceBand
# 8056       1.0.1    4.0 and up      Free
# 7206       1.1.0  2.3.3 and up      Free
# 6970       1.0.7    4.0 and up      Free
# 4149           1  2.3.3 and up      Free
# 1963         1.2    4.2 and up      Free

# %%
apps['Content Rating'].value_counts()
# Out:
# Everyone           7903
# Teen               1036
# Mature 17+          393
# Everyone 10+        321
# Adults only 18+       3
# Unrated               2
# Name: Content Rating, dtype: int64

# %%
# Cast content rating to categorical
apps['Content Rating'] = apps['Content Rating'].astype('category')

# %%
# Cast last update to date
apps['Last Updated'] = apps['Last Updated'].astype('datetime64[ns]')

# %%
apps['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
# Cast android version to categorical
apps['Android Ver'] = apps['Android Ver'].astype('category')

# %%
apps['Genres'].unique()
# Out:
# array(['Art & Design', 'Art & Design;Creativity', 'Auto & Vehicles',
#        'Beauty', 'Books & Reference', 'Business', 'Comics',
#        'Comics;Creativity', 'Communication', 'Dating', 'Education',
#        'Education;Creativity', 'Education;Education',
#        'Education;Pretend Play', 'Education;Brain Games', 'Entertainment',
#        'Entertainment;Brain Games', 'Entertainment;Creativity',
#        'Entertainment;Music & Video', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play', 'Puzzle', 'Racing',
#        'Sports', 'Casual', 'Arcade', 'Trivia', 'Simulation', 'Action',
#        'Word', 'Role Playing', 'Strategy', 'Board',
#        'Simulation;Education', 'Adventure', 'Card',
#        'Action;Action & Adventure', 'Music', 'Casual;Brain Games',
#        'Educational;Creativity', 'Puzzle;Brain Games',
#        'Educational;Education', 'Card;Brain Games', 'Casual;Pretend Play',
#        'Educational;Brain Games', 'Art & Design;Pretend Play',
#        'Entertainment;Education', 'Casual;Education', 'Casual;Creativity',
#        'Music;Music & Video', 'Educational;Pretend Play',
#        'Arcade;Pretend Play', 'Casual;Action & Adventure',
#        'Adventure;Action & Adventure', 'Simulation;Pretend Play',
#        'Puzzle;Creativity', 'Simulation;Action & Adventure',
#        'Racing;Action & Adventure', 'Sports;Action & Adventure',
#        'Educational;Action & Adventure', 'Arcade;Action & Adventure',
#        'Entertainment;Action & Adventure',
#        'Art & Design;Action & Adventure', 'Puzzle;Action & Adventure',
#        'Education;Action & Adventure', 'Strategy;Action & Adventure',
#        'Music & Audio;Music & Video', 'Health & Fitness;Education',
#        'Board;Action & Adventure', 'Board;Brain Games',
#        'Board;Pretend Play', 'Casual;Music & Video',
#        'Education;Music & Video', 'Role Playing;Pretend Play',
#        'Entertainment;Pretend Play', 'Role Playing;Action & Adventure',
#        'Card;Action & Adventure', 'Medical', 'Social', 'Shopping',
#        'Photography', 'Travel & Local',
#        'Travel & Local;Action & Adventure', 'Tools', 'Tools;Education',
#        'Personalization', 'Productivity', 'Parenting',
#        'Parenting;Music & Video', 'Parenting;Education',
#        'Parenting;Brain Games', 'Weather', 'Video Players & Editors',
#        'News & Magazines', 'Maps & Navigation',
#        'Health & Fitness;Action & Adventure', 'Educational', 'Casino',
#        'Adventure;Brain Games', 'Video Players & Editors;Music & Video',
#        'Trivia;Education', 'Lifestyle;Education',
#        'Books & Reference;Creativity', 'Books & Reference;Education',
#        'Puzzle;Education', 'Adventure;Education',
#        'Role Playing;Education', 'Role Playing;Brain Games',
#        'Strategy;Education', 'Racing;Pretend Play',
#        'Communication;Creativity', 'Strategy;Creativity'], dtype=object)

# %% [markdown]
# Hmm, multiple genres huh? What should we do? Use a ralational-db?

# %%
apps[apps['Genres'].str.contains(';')]
# Out:
#                                                      App        Category  \
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun  ART_AND_DESIGN
# 26                         Colorfit - Drawing & Coloring  ART_AND_DESIGN
# 43                                         Paint Splash!  ART_AND_DESIGN
# 301                      Unicorn Pokez - Color By Number          COMICS
# 711                                             Mermaids       EDUCATION
# 712       Learn Japanese, Korean, Chinese Offline & Free       EDUCATION
# 715                             Dinosaurs Coloring Pages       EDUCATION
# 716                                  Cars Coloring Pages       EDUCATION
# 728        Free intellectual training game application |       EDUCATION
# 729                                   ABC Preschool Free       EDUCATION
# 745               NeuroNation - Focus and Brain Training       EDUCATION
# 748                               Memorado - Brain Games       EDUCATION
# 847    Rosetta Stone: Learn to Speak & Read New Langu...       EDUCATION
# 10218     Communication;Creativity   2018-08-06        33.0.0.22.76
# 10390   Entertainment;Pretend Play   2018-02-10                 5.1
# 10394        Educational;Education   2018-06-06              1.15.2
# 10438      Art & Design;Creativity   2018-05-15  Varies with device
# 10493          Casual;Pretend Play   2018-07-16            2.1.3181
# 10502    Racing;Action & Adventure   2018-08-07                3.53
# 10506          Casual;Pretend Play   2018-04-11               1.0.5
# 10526          Strategy;Creativity   2018-07-23               2.4.9
#
#               Android Ver  PriceBand
# 4              4.4 and up       Free
# 9            4.0.3 and up       Free
# 26           4.0.3 and up       Free
# 43             4.1 and up       Free
# 301            4.4 and up       Free
# 711            4.1 and up       Free
# 712            4.2 and up       Free
# 715            4.0 and up       Free
# 716            4.0 and up       Free
# 728            4.4 and up       Free
# 729            2.3 and up       Free
# 745          4.0.3 and up       Free
# 748            4.1 and up       Free
# 847            5.0 and up       Free
# 849            4.1 and up       Free
# 851          4.0.3 and up     Normal
# 854            4.4 and up     Normal
# 884            4.1 and up       Free
# 887            4.4 and up       Free
# 948            4.4 and up       Free
# 986            4.4 and up       Free
# 989    Varies with device       Free
# 1565           4.0 and up       Free
# 1835           4.4 and up     Normal
# 1955   Varies with device       Free
# 2015         4.0.3 and up       Free
# 2017         4.0.3 and up       Free
# 2018         4.0.3 and up       Free
# 2019         4.0.3 and up       Free
# 2021         4.0.3 and up       Free
# ...                   ...        ...
# 9668           4.1 and up       Free
# 9669           4.1 and up  Not cheap
# 9671           4.0 and up       Free
# 9672           4.1 and up  Not cheap
# 9673           4.1 and up       Free
# 9674           4.0 and up       Free
# 9676         4.0.3 and up       Free
# 9677           4.1 and up       Free
# 9678           4.2 and up  Not cheap
# 9680           4.2 and up       Free
# 9682           4.1 and up       Free
# 9683           4.1 and up       Free
# 9684         4.0.3 and up       Free
# 9687           4.1 and up       Free
# 9688           4.1 and up       Free
# 9717           4.1 and up  Not cheap
# 9725           2.3 and up       Free
# 9741           4.1 and up       Free
# 9831           2.2 and up       Free
# 9846           4.2 and up       Free
# 9936           4.1 and up       Free
# 10098        4.0.3 and up       Free
# 10218          4.4 and up       Free
# 10390          4.2 and up       Free
# 10394          4.4 and up       Free
# 10438          4.1 and up       Free
# 10493        4.0.3 and up       Free
# 10502          4.2 and up       Free
# 10506          4.1 and up       Free
# 10526        4.0.3 and up       Free
#
# [392 rows x 14 columns]

# %% [markdown]
# There are meaningless sub genres like: "Education;Education"? What?
#
# So i decide to elimnate these sub-genres after the ;
#
# Then make them categorical

# %%
apps['Genres'] = apps['Genres'].str.split(';').str[0].astype('category')

# %%
apps['Genres'].value_counts()
# Out:
# Tools                      829
# Entertainment              592
# Education                  580
# Business                   419
# Medical                    396
# Personalization            376
# Productivity               374
# Lifestyle                  370
# Finance                    345
# Sports                     335
# Communication              317
# Action                     311
# Health & Fitness           289
# Photography                281
# News & Magazines           254
# Social                     239
# Books & Reference          225
# Casual                     224
# Travel & Local             219
# Simulation                 206
# Shopping                   202
# Arcade                     200
# Dating                     170
# Video Players & Editors    165
# Puzzle                     142
# Maps & Navigation          131
# Role Playing               115
# Food & Drink               112
# Racing                     108
# Educational                102
# Strategy                    98
# Auto & Vehicles             85
# Libraries & Demo            84
# Adventure                   80
# Weather                     79
# House & Home                73
# Art & Design                65
# Events                      64
# Board                       60
# Parenting                   60
# Comics                      56
# Beauty                      53
# Card                        49
# Casino                      39
# Trivia                      39
# Word                        23
# Music                       22
# Music & Audio                1
# Name: Genres, dtype: int64

# %% [markdown]
# Beautiful, but look at the end of the list..
#
# There is just 1 app fall in the genre of "Music & Audio" so i decide to merge it with "Music"

# %%
apps['Genres'].replace('Music & Audio', 'Music',inplace = True)

# %% [markdown]
# ## Double-Check

# %%
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9658 entries, 0 to 10840
# Data columns (total 14 columns):
# App               9658 non-null object
# Category          9658 non-null category
# Rating            8196 non-null float64
# Reviews           9658 non-null int64
# Size              9658 non-null int64
# Installs          9658 non-null int64
# Type              9658 non-null category
# Price             9658 non-null float64
# Content Rating    9658 non-null category
# Genres            9658 non-null category
# Last Updated      9658 non-null datetime64[ns]
# Current Ver       9650 non-null object
# Android Ver       9656 non-null category
# PriceBand         9658 non-null object
# dtypes: category(5), datetime64[ns](1), float64(2), int64(3), object(3)
# memory usage: 806.6+ KB

# %% [markdown]
# "Rating" can contains nan value because there are apps that didnt receive any review form users or they just dont have any user (sadly)
#
# But "Android Ver", "Current" cannot contains nan value, so:

# %%
apps['Current Ver'].fillna('1.0', inplace=True)
apps['Android Ver'].fillna('1.5 and up', inplace=True)

# %% [markdown]
# ### Export to csv

# %%
apps.to_csv('google-play-store-cleanned.csv')

# %% [markdown]
# ## Analysis Data

# %%
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9658 entries, 0 to 10840
# Data columns (total 14 columns):
# App               9658 non-null object
# Category          9658 non-null category
# Rating            8196 non-null float64
# Reviews           9658 non-null int64
# Size              9658 non-null int64
# Installs          9658 non-null int64
# Type              9658 non-null category
# Price             9658 non-null float64
# Content Rating    9658 non-null category
# Genres            9658 non-null category
# Last Updated      9658 non-null datetime64[ns]
# Current Ver       9658 non-null object
# Android Ver       9658 non-null category
# PriceBand         9658 non-null object
# dtypes: category(5), datetime64[ns](1), float64(2), int64(3), object(3)
# memory usage: 806.6+ KB

# %%
apps.describe()
# Out:
#             Rating       Reviews         Size      Installs        Price
# count  8196.000000  9.658000e+03  9658.000000  9.658000e+03  9658.000000
# mean      4.173219  2.166737e+05    19.915096  7.795055e+06     1.097344
# std       0.536269  1.830831e+06    20.754701  5.377264e+07    16.852487
# min       1.000000  0.000000e+00     0.000000  0.000000e+00     0.000000
# 25%       4.000000  2.500000e+01     5.000000  1.000000e+03     0.000000
# 50%       4.300000  9.690000e+02    13.000000  1.000000e+05     0.000000
# 75%       4.500000  2.940800e+04    27.000000  1.000000e+06     0.000000
# max       5.000000  7.812821e+07   100.000000  1.000000e+09   400.000000

# %%
apps.corr()
sns.heatmap(apps.corr(), annot=True, cmap='PuBuGn')
# Out:
#             Rating   Reviews      Size  Installs     Price
# Rating    1.000000  0.055137  0.058684  0.040221 -0.021102
# Reviews   0.055137  1.000000  0.073786  0.625029 -0.007589
# Size      0.058684  0.073786  1.000000  0.039477 -0.021912
# Installs  0.040221  0.625029  0.039477  1.000000 -0.009407
# Price    -0.021102 -0.007589 -0.021912 -0.009407  1.000000

# %% [markdown]
# Looks like only installs and reviews seem related: the higher installs, the higher reivews.
#
# Note that installs and review doesnt affect rating at all.

# %%
sns.pairplot(data = apps)

# %%
apps.groupby(by = 'Category').sum().sort_values(by='Installs')
# Out:
#                      Rating    Reviews   Size     Installs    Price
# Category
# 1.9                     0.0          0      0            0     0.00
# EVENTS                199.6     161018    873     15973161   109.99
# BEAUTY                179.7     396240    714     27197050     0.00
# PARENTING             215.0     958331   1335     31521110     9.58
# MEDICAL              1213.3    1287083   7506     39203077   982.71
# COMICS                225.8    2342399    757     44981150     0.00
# LIBRARIES_AND_DEMO    267.4     906846    864     52995910     0.99
# AUTO_AND_VEHICLES     305.9    1163666   1684     53130211    13.47
# HOUSE_AND_HOME        252.6    1929789   1166     97202461     0.00
# ART_AND_DESIGN        257.2    1410046    731    113238100     5.97
# DATING                529.4    3623840   2631    140925107    20.45
# EDUCATION             439.5    5583607   1836    176951000     7.98
# FOOD_AND_DRINK        392.1    6325986   2274    211798751     8.48
# WEATHER               305.5   12294246    974    361100520    32.42
# FINANCE              1242.9   12662872   5910    455348734  2900.83
# MAPS_AND_NAVIGATION   476.3   17720178   2110    503281890    26.95
# LIFESTYLE            1232.1   11832055   5374    503823539  2360.87
# BUSINESS             1073.3    9702179   5692    692164865   175.29
# ENTERTAINMENT         324.8   14658985   1837    708660000     7.98
# HEALTH_AND_FITNESS   1030.8   21039814   5844   1134022512    64.35
# SPORTS               1105.3   59406934   7900   1296474498   100.00
# SHOPPING              761.5   44524852   3079   1400348785     5.48
# PERSONALIZATION      1291.0   53532177   4113   1532494782   150.48
# BOOKS_AND_REFERENCE   734.3   16722873   2856   1665969576   119.77
# NEWS_AND_MAGAZINES    840.8   23120896   3096   2369217760     3.98
# TRAVEL_AND_LOCAL      761.0   26817033   5276   2894887146    49.95
# VIDEO_PLAYERS         598.4   67324804   2520   3917002720    10.46
# PHOTOGRAPHY          1093.0  105556805   4322   4658147655   118.28
# SOCIAL                862.2  227802363   3720   5487867902    15.97
# PRODUCTIVITY         1259.2   55570346   4519   5788091369   250.93
# TOOLS                2909.0  229433729   6973   8102771915   267.25
# FAMILY               7038.4  345758056  52176   8870642505  2409.84
# GAME                 3727.2  425239248  38191  10897924415   284.31
# COMMUNICATION        1059.2  285824817   3487  11039276251    83.14

# %%
sns.distplot(apps[apps['Rating'].notna()]['Rating'])

# %% [markdown]
# Average of rating of applications in store is around ~4.3 which is very high

# %%
plt.subplots(figsize=(12,12))
sns.countplot(y='Category', data=apps, order = apps['Category'].value_counts().index)
# Out:
# (<Figure size 864x864 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1a1fec96d8>)

# %% [markdown]
# Game and Family category are the most appearances for application in store

# %%
sns.catplot(y="Category", x="Rating", data=apps, kind="box", height = 10)

# %% [markdown]
# Rating of application in each category is not different too much
